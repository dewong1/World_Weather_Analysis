# %%
# Import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %% [markdown]
# # Retrieving Nearest City (new set lats/lngs)

# %%
# Create a set of 2,000 random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000) 

lat_lngs = zip(lats, lngs)

# %%
# Create a list for holding the cities
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 0

# %% [markdown]
# # Performing an API Call with the OpenWeatherMap

# %%
# Import dependencies

import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | saskylakh
# Processing Record 3 of Set 1 | chokurdakh
# Processing Record 4 of Set 1 | salur
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | a
# City not found. Skipping...
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | abapo
# Processing Record 9 of Set 1 | fredericton
# Processing Record 10 of Set 1 | chapais
# Processing Record 11 of Set 1 | contamana
# Processing Record 12 of Set 1 | vestbygda
# City not found. Skipping...
# Processing Record 13 of Set 1 | puerto madryn
# Processing Record 14 of Set 1 | bengkulu
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | saint-augustin
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | hasaki
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | muros
# Processing Record 31 of Set 1 | westport
# Processing Record 32 of Set 1 | egvekinot
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | upernavik
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | labuhan
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | bilibino
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | sarangani
# Processing Record 47 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | alofi
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | mahebourg
# Processing Record 4 of Set 2 | ceyhan
# Processing Record 5 of Set 2 | abu samrah
# Processing Record 6 of Set 2 | catuday
# Processing Record 7 of Set 2 | leshukonskoye
# Processing Record 8 of Set 2 | ancud
# Processing Record 9 of Set 2 | coihaique
# Processing Record 10 of Set 2 | zaysan
# Processing Record 11 of Set 2 | college
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | staryy nadym
# Processing Record 14 of Set 2 | reims
# Processing Record 15 of Set 2 | bambous virieux
# Processing Record 16 of Set 2 | chimore
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | husavik
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | kavaratti
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | lagoa
# Processing Record 25 of Set 2 | yazman
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | ust-maya
# Processing Record 28 of Set 2 | nuuk
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | milingimbi
# City not found. Skipping...
# Processing Record 31 of Set 2 | manaure
# Processing Record 32 of Set 2 | nome
# Processing Record 33 of Set 2 | moose factory
# Processing Record 34 of Set 2 | pevek
# Processing Record 35 of Set 2 | geresk
# City not found. Skipping...
# Processing Record 36 of Set 2 | nehe
# Processing Record 37 of Set 2 | kavieng
# Processing Record 38 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 2 | morros
# Processing Record 40 of Set 2 | tuatapere
# Processing Record 41 of Set 2 | sao felix do xingu
# Processing Record 42 of Set 2 | mecca
# Processing Record 43 of Set 2 | aguimes
# Processing Record 44 of Set 2 | poshekhonye
# Processing Record 45 of Set 2 | yulara
# Processing Record 46 of Set 2 | souillac
# Processing Record 47 of Set 2 | riyadh
# Processing Record 48 of Set 2 | port hardy
# Processing Record 49 of Set 2 | hualmay
# Processing Record 50 of Set 2 | sisimiut
# Processing Record 1 of Set 3 | kenai
# Processing Record 2 of Set 3 | meulaboh
# Processing Record 3 of Set 3 | new norfolk
# Processing Record 4 of Set 3 | tara
# Processing Record 5 of Set 3 | manokwari
# Processing Record 6 of Set 3 | smithers
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | paoua
# Processing Record 9 of Set 3 | ailigandi
# Processing Record 10 of Set 3 | tigre
# Processing Record 11 of Set 3 | naigarhi
# Processing Record 12 of Set 3 | viransehir
# Processing Record 13 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 3 | varhaug
# Processing Record 15 of Set 3 | bubaque
# Processing Record 16 of Set 3 | havre-saint-pierre
# Processing Record 17 of Set 3 | flinders
# Processing Record 18 of Set 3 | guerrero negro
# Processing Record 19 of Set 3 | antalaha
# Processing Record 20 of Set 3 | malkangiri
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | atar
# Processing Record 23 of Set 3 | san lorenzo
# Processing Record 24 of Set 3 | dwarka
# Processing Record 25 of Set 3 | salinas
# Processing Record 26 of Set 3 | puri
# Processing Record 27 of Set 3 | avarua
# Processing Record 28 of Set 3 | port-gentil
# Processing Record 29 of Set 3 | aklavik
# Processing Record 30 of Set 3 | hobe sound
# Processing Record 31 of Set 3 | kudahuvadhoo
# Processing Record 32 of Set 3 | port lincoln
# Processing Record 33 of Set 3 | faya
# Processing Record 34 of Set 3 | trapani
# Processing Record 35 of Set 3 | georgetown
# Processing Record 36 of Set 3 | virginia beach
# Processing Record 37 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 3 | grindavik
# Processing Record 39 of Set 3 | turtkul
# City not found. Skipping...
# Processing Record 40 of Set 3 | narsaq
# Processing Record 41 of Set 3 | new iberia
# Processing Record 42 of Set 3 | henties bay
# Processing Record 43 of Set 3 | tura
# Processing Record 44 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 3 | salalah
# Processing Record 47 of Set 3 | hambantota
# Processing Record 48 of Set 3 | coquimbo
# Processing Record 49 of Set 3 | bonthe
# Processing Record 50 of Set 3 | mataura
# Processing Record 1 of Set 4 | mutoko
# Processing Record 2 of Set 4 | sola
# Processing Record 3 of Set 4 | kruisfontein
# Processing Record 4 of Set 4 | aykhal
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | gat
# Processing Record 7 of Set 4 | northam
# Processing Record 8 of Set 4 | ellsworth
# Processing Record 9 of Set 4 | abiy adi
# City not found. Skipping...
# Processing Record 10 of Set 4 | port blair
# Processing Record 11 of Set 4 | san pedro
# Processing Record 12 of Set 4 | hobart
# Processing Record 13 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 4 | beringovskiy
# Processing Record 15 of Set 4 | hamilton
# Processing Record 16 of Set 4 | palana
# Processing Record 17 of Set 4 | lavrentiya
# Processing Record 18 of Set 4 | mar del plata
# Processing Record 19 of Set 4 | benjamin constant
# Processing Record 20 of Set 4 | nakambala
# Processing Record 21 of Set 4 | sao joao da barra
# Processing Record 22 of Set 4 | nikolskoye
# Processing Record 23 of Set 4 | nongan
# Processing Record 24 of Set 4 | provideniya
# Processing Record 25 of Set 4 | garden city
# Processing Record 26 of Set 4 | kirakira
# Processing Record 27 of Set 4 | vanimo
# Processing Record 28 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 29 of Set 4 | katsuura
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 4 | port macquarie
# Processing Record 32 of Set 4 | camacha
# Processing Record 33 of Set 4 | codrington
# Processing Record 34 of Set 4 | karabash
# Processing Record 35 of Set 4 | rockport
# Processing Record 36 of Set 4 | guanay
# Processing Record 37 of Set 4 | maniitsoq
# Processing Record 38 of Set 4 | clyde river
# Processing Record 39 of Set 4 | pisco
# Processing Record 40 of Set 4 | grimmen
# Processing Record 41 of Set 4 | geraldton
# Processing Record 42 of Set 4 | mahibadhoo
# Processing Record 43 of Set 4 | whyalla
# Processing Record 44 of Set 4 | penco
# Processing Record 45 of Set 4 | taltal
# Processing Record 46 of Set 4 | little current
# Processing Record 47 of Set 4 | karratha
# Processing Record 48 of Set 4 | avera
# Processing Record 49 of Set 4 | poum
# Processing Record 50 of Set 4 | norman wells
# Processing Record 1 of Set 5 | bilma
# Processing Record 2 of Set 5 | solnechnyy
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | abu jubayhah
# City not found. Skipping...
# Processing Record 5 of Set 5 | wanning
# Processing Record 6 of Set 5 | bereda
# Processing Record 7 of Set 5 | palmas bellas
# Processing Record 8 of Set 5 | kortkeros
# Processing Record 9 of Set 5 | cidreira
# Processing Record 10 of Set 5 | tasiilaq
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 5 | edd
# Processing Record 14 of Set 5 | assiniboia
# Processing Record 15 of Set 5 | airai
# Processing Record 16 of Set 5 | shimanovsk
# Processing Record 17 of Set 5 | port elizabeth
# Processing Record 18 of Set 5 | ipixuna
# Processing Record 19 of Set 5 | mount isa
# Processing Record 20 of Set 5 | laguna
# Processing Record 21 of Set 5 | cabedelo
# Processing Record 22 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 5 | kirishi
# Processing Record 24 of Set 5 | olafsvik
# Processing Record 25 of Set 5 | ilhabela
# Processing Record 26 of Set 5 | upington
# Processing Record 27 of Set 5 | talnakh
# Processing Record 28 of Set 5 | opuwo
# Processing Record 29 of Set 5 | billings
# Processing Record 30 of Set 5 | san ignacio
# Processing Record 31 of Set 5 | warkworth
# Processing Record 32 of Set 5 | castro
# Processing Record 33 of Set 5 | talakan
# Processing Record 34 of Set 5 | tingi
# Processing Record 35 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 5 | cayenne
# Processing Record 37 of Set 5 | dzilam gonzalez
# Processing Record 38 of Set 5 | turbat
# Processing Record 39 of Set 5 | conceicao do araguaia
# Processing Record 40 of Set 5 | simao
# Processing Record 41 of Set 5 | meadow lake
# Processing Record 42 of Set 5 | sioux lookout
# Processing Record 43 of Set 5 | omsukchan
# Processing Record 44 of Set 5 | krasnolesnyy
# Processing Record 45 of Set 5 | dosso
# Processing Record 46 of Set 5 | ikalamavony
# Processing Record 47 of Set 5 | novobiryusinskiy
# Processing Record 48 of Set 5 | barranca
# Processing Record 49 of Set 5 | naze
# Processing Record 50 of Set 5 | usinsk
# Processing Record 1 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 6 | east london
# Processing Record 3 of Set 6 | saint anthony
# Processing Record 4 of Set 6 | dinguiraye
# Processing Record 5 of Set 6 | kineta
# Processing Record 6 of Set 6 | koumac
# Processing Record 7 of Set 6 | kodinsk
# Processing Record 8 of Set 6 | sur
# Processing Record 9 of Set 6 | trinidad
# Processing Record 10 of Set 6 | dongsheng
# Processing Record 11 of Set 6 | edeia
# Processing Record 12 of Set 6 | la uribe
# City not found. Skipping...
# Processing Record 13 of Set 6 | vao
# Processing Record 14 of Set 6 | trelew
# Processing Record 15 of Set 6 | lorca
# Processing Record 16 of Set 6 | greece
# Processing Record 17 of Set 6 | odesskoye
# Processing Record 18 of Set 6 | oranjestad
# Processing Record 19 of Set 6 | casma
# Processing Record 20 of Set 6 | russell
# Processing Record 21 of Set 6 | quimperle
# Processing Record 22 of Set 6 | iqaluit
# Processing Record 23 of Set 6 | lata
# Processing Record 24 of Set 6 | urzhum
# Processing Record 25 of Set 6 | vityazevo
# Processing Record 26 of Set 6 | balvi
# Processing Record 27 of Set 6 | maarianhamina
# Processing Record 28 of Set 6 | cherskiy
# Processing Record 29 of Set 6 | kidal
# Processing Record 30 of Set 6 | tres arroyos
# Processing Record 31 of Set 6 | warrnambool
# Processing Record 32 of Set 6 | calbuco
# Processing Record 33 of Set 6 | constitucion
# Processing Record 34 of Set 6 | kysyl-syr
# Processing Record 35 of Set 6 | yuanping
# Processing Record 36 of Set 6 | buraydah
# Processing Record 37 of Set 6 | ileza
# Processing Record 38 of Set 6 | nioro
# Processing Record 39 of Set 6 | esperance
# Processing Record 40 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 6 | petrov val
# Processing Record 42 of Set 6 | broome
# Processing Record 43 of Set 6 | lufilufi
# Processing Record 44 of Set 6 | baruun-urt
# Processing Record 45 of Set 6 | tiksi
# Processing Record 46 of Set 6 | severo-kurilsk
# Processing Record 47 of Set 6 | mizdah
# Processing Record 48 of Set 6 | vacaria
# Processing Record 49 of Set 6 | alexandria
# Processing Record 50 of Set 6 | sembakung
# Processing Record 1 of Set 7 | tongzi
# Processing Record 2 of Set 7 | mouzakion
# City not found. Skipping...
# Processing Record 3 of Set 7 | metehara
# City not found. Skipping...
# Processing Record 4 of Set 7 | usta muhammad
# Processing Record 5 of Set 7 | sitka
# Processing Record 6 of Set 7 | tibagi
# Processing Record 7 of Set 7 | adrar
# Processing Record 8 of Set 7 | tiznit
# Processing Record 9 of Set 7 | asau
# Processing Record 10 of Set 7 | kletnya
# Processing Record 11 of Set 7 | comodoro rivadavia
# Processing Record 12 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 7 | half moon bay
# Processing Record 14 of Set 7 | pijijiapan
# Processing Record 15 of Set 7 | mafra
# Processing Record 16 of Set 7 | dawlatabad
# Processing Record 17 of Set 7 | sechelt
# Processing Record 18 of Set 7 | san patricio
# Processing Record 19 of Set 7 | dudinka
# Processing Record 20 of Set 7 | madimba
# Processing Record 21 of Set 7 | nouadhibou
# Processing Record 22 of Set 7 | buala
# Processing Record 23 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 24 of Set 7 | eydhafushi
# Processing Record 25 of Set 7 | yamandu
# Processing Record 26 of Set 7 | damghan
# Processing Record 27 of Set 7 | namatanai
# Processing Record 28 of Set 7 | katete
# Processing Record 29 of Set 7 | januaria
# Processing Record 30 of Set 7 | tafo
# Processing Record 31 of Set 7 | taperoa
# Processing Record 32 of Set 7 | minas novas
# Processing Record 33 of Set 7 | komsomolskiy
# Processing Record 34 of Set 7 | vila franca do campo
# Processing Record 35 of Set 7 | boende
# Processing Record 36 of Set 7 | soyo
# Processing Record 37 of Set 7 | klaksvik
# Processing Record 38 of Set 7 | bojnurd
# Processing Record 39 of Set 7 | mitsamiouli
# Processing Record 40 of Set 7 | norilsk
# Processing Record 41 of Set 7 | paracuru
# Processing Record 42 of Set 7 | san carlos
# Processing Record 43 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 7 | ankara
# Processing Record 45 of Set 7 | saint george
# Processing Record 46 of Set 7 | ngunguru
# Processing Record 47 of Set 7 | mindelo
# Processing Record 48 of Set 7 | krapivinskiy
# Processing Record 49 of Set 7 | pachelma
# Processing Record 50 of Set 7 | pitea
# Processing Record 1 of Set 8 | richards bay
# Processing Record 2 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 8 | mayumba
# Processing Record 4 of Set 8 | yeppoon
# Processing Record 5 of Set 8 | qujing
# Processing Record 6 of Set 8 | muravlenko
# Processing Record 7 of Set 8 | luderitz
# Processing Record 8 of Set 8 | taoudenni
# Processing Record 9 of Set 8 | mount gambier
# Processing Record 10 of Set 8 | linhares
# Processing Record 11 of Set 8 | grahamstown
# Processing Record 12 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 8 | vila velha
# Processing Record 14 of Set 8 | desert hot springs
# Processing Record 15 of Set 8 | tocopilla
# Processing Record 16 of Set 8 | ilulissat
# Processing Record 17 of Set 8 | terrace bay
# Processing Record 18 of Set 8 | namibe
# Processing Record 19 of Set 8 | oussouye
# Processing Record 20 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 21 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 8 | saint-joseph
# Processing Record 23 of Set 8 | hailey
# Processing Record 24 of Set 8 | bassano
# Processing Record 25 of Set 8 | launceston
# Processing Record 26 of Set 8 | arilje
# Processing Record 27 of Set 8 | walvis bay
# Processing Record 28 of Set 8 | bol
# Processing Record 29 of Set 8 | miri
# Processing Record 30 of Set 8 | athabasca
# Processing Record 31 of Set 8 | keningau
# Processing Record 32 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 8 | tingo maria
# Processing Record 34 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 35 of Set 8 | ranfurly
# Processing Record 36 of Set 8 | ambilobe
# Processing Record 37 of Set 8 | carahue
# Processing Record 38 of Set 8 | shagonar
# Processing Record 39 of Set 8 | eyl
# Processing Record 40 of Set 8 | tombouctou
# Processing Record 41 of Set 8 | jiangyou
# Processing Record 42 of Set 8 | letterkenny
# Processing Record 43 of Set 8 | sillod
# Processing Record 44 of Set 8 | itaituba
# Processing Record 45 of Set 8 | chase
# Processing Record 46 of Set 8 | villazon
# Processing Record 47 of Set 8 | najran
# Processing Record 48 of Set 8 | mehamn
# Processing Record 49 of Set 8 | srednekolymsk
# Processing Record 50 of Set 8 | bandarbeyla
# Processing Record 1 of Set 9 | almeria
# Processing Record 2 of Set 9 | christchurch
# Processing Record 3 of Set 9 | shingu
# Processing Record 4 of Set 9 | port hedland
# Processing Record 5 of Set 9 | kaeo
# Processing Record 6 of Set 9 | changping
# Processing Record 7 of Set 9 | gallup
# Processing Record 8 of Set 9 | umm lajj
# Processing Record 9 of Set 9 | arroyo
# Processing Record 10 of Set 9 | gizo
# Processing Record 11 of Set 9 | nelson bay
# Processing Record 12 of Set 9 | ojinaga
# Processing Record 13 of Set 9 | huarmey
# Processing Record 14 of Set 9 | sorland
# Processing Record 15 of Set 9 | kautokeino
# Processing Record 16 of Set 9 | shimoda
# Processing Record 17 of Set 9 | the valley
# Processing Record 18 of Set 9 | dhidhdhoo
# Processing Record 19 of Set 9 | yatou
# Processing Record 20 of Set 9 | kouango
# Processing Record 21 of Set 9 | vaitape
# Processing Record 22 of Set 9 | garissa
# Processing Record 23 of Set 9 | sao filipe
# Processing Record 24 of Set 9 | belyy yar
# Processing Record 25 of Set 9 | methoni
# Processing Record 26 of Set 9 | rameswaram
# Processing Record 27 of Set 9 | tomatlan
# Processing Record 28 of Set 9 | garmsar
# Processing Record 29 of Set 9 | broken hill
# Processing Record 30 of Set 9 | trenggalek
# Processing Record 31 of Set 9 | ghugus
# Processing Record 32 of Set 9 | huilong
# Processing Record 33 of Set 9 | kieta
# Processing Record 34 of Set 9 | tulu bolo
# Processing Record 35 of Set 9 | severodvinsk
# Processing Record 36 of Set 9 | tsiroanomandidy
# Processing Record 37 of Set 9 | andros town
# Processing Record 38 of Set 9 | price
# Processing Record 39 of Set 9 | yerbogachen
# Processing Record 40 of Set 9 | dingle
# Processing Record 41 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 9 | palauig
# Processing Record 44 of Set 9 | itarema
# Processing Record 45 of Set 9 | kamaishi
# Processing Record 46 of Set 9 | araguacu
# Processing Record 47 of Set 9 | mogadishu
# Processing Record 48 of Set 9 | sao paulo de olivenca
# Processing Record 49 of Set 9 | anadyr
# Processing Record 50 of Set 9 | anderson
# Processing Record 1 of Set 10 | vestmanna
# Processing Record 2 of Set 10 | ulladulla
# Processing Record 3 of Set 10 | batagay-alyta
# Processing Record 4 of Set 10 | banepa
# Processing Record 5 of Set 10 | nadvoitsy
# Processing Record 6 of Set 10 | ndjole
# Processing Record 7 of Set 10 | nyimba
# Processing Record 8 of Set 10 | krasnoselkup
# Processing Record 9 of Set 10 | pankrushikha
# Processing Record 10 of Set 10 | lodja
# Processing Record 11 of Set 10 | beloha
# Processing Record 12 of Set 10 | kailua
# Processing Record 13 of Set 10 | gewane
# Processing Record 14 of Set 10 | longyearbyen
# Processing Record 15 of Set 10 | yar-sale
# Processing Record 16 of Set 10 | leningradskiy
# Processing Record 17 of Set 10 | nouakchott
# Processing Record 18 of Set 10 | kyra
# Processing Record 19 of Set 10 | ramona
# Processing Record 20 of Set 10 | caraballeda
# Processing Record 21 of Set 10 | huaihua
# Processing Record 22 of Set 10 | chikwawa
# Processing Record 23 of Set 10 | kununurra
# Processing Record 24 of Set 10 | merauke
# Processing Record 25 of Set 10 | borogontsy
# Processing Record 26 of Set 10 | viedma
# Processing Record 27 of Set 10 | ocos
# Processing Record 28 of Set 10 | abaete
# Processing Record 29 of Set 10 | port augusta
# Processing Record 30 of Set 10 | bonavista
# Processing Record 31 of Set 10 | alice springs
# Processing Record 32 of Set 10 | beyneu
# Processing Record 33 of Set 10 | sungaipenuh
# Processing Record 34 of Set 10 | nador
# Processing Record 35 of Set 10 | damietta
# Processing Record 36 of Set 10 | buchanan
# Processing Record 37 of Set 10 | pala
# Processing Record 38 of Set 10 | deputatskiy
# Processing Record 39 of Set 10 | lac du bonnet
# Processing Record 40 of Set 10 | presidencia roque saenz pena
# Processing Record 41 of Set 10 | mae sai
# Processing Record 42 of Set 10 | hernani
# Processing Record 43 of Set 10 | moerai
# Processing Record 44 of Set 10 | camocim
# Processing Record 45 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 46 of Set 10 | kitimat
# Processing Record 47 of Set 10 | san felipe
# Processing Record 48 of Set 10 | chernyshevskiy
# Processing Record 49 of Set 10 | waipawa
# Processing Record 50 of Set 10 | lewisville
# Processing Record 1 of Set 11 | tooele
# Processing Record 2 of Set 11 | nanortalik
# Processing Record 3 of Set 11 | quatre cocos
# Processing Record 4 of Set 11 | galle
# Processing Record 5 of Set 11 | sai buri
# Processing Record 6 of Set 11 | tupik
# Processing Record 7 of Set 11 | weyburn
# Processing Record 8 of Set 11 | lagoa vermelha
# Processing Record 9 of Set 11 | ruteng
# Processing Record 10 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 11 of Set 11 | baiquan
# Processing Record 12 of Set 11 | comarapa
# Processing Record 13 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 14 of Set 11 | disna
# Processing Record 15 of Set 11 | baghdad
# Processing Record 16 of Set 11 | makakilo city
# Processing Record 17 of Set 11 | kytlym
# City not found. Skipping...
# Processing Record 18 of Set 11 | urusha
# Processing Record 19 of Set 11 | nantucket
# Processing Record 20 of Set 11 | chabua
# Processing Record 21 of Set 11 | byron bay
# Processing Record 22 of Set 11 | kamina
# Processing Record 23 of Set 11 | itoman
# Processing Record 24 of Set 11 | charters towers
# Processing Record 25 of Set 11 | nizhniy odes
# Processing Record 26 of Set 11 | moron
# Processing Record 27 of Set 11 | redmond
# Processing Record 28 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 11 | mutis
# Processing Record 30 of Set 11 | olinda
# Processing Record 31 of Set 11 | rizhao
# Processing Record 32 of Set 11 | faanui
# Processing Record 33 of Set 11 | waitati
# Processing Record 34 of Set 11 | tautira
# Processing Record 35 of Set 11 | pasni
# Processing Record 36 of Set 11 | bonnyville
# Processing Record 37 of Set 11 | thinadhoo
# Processing Record 38 of Set 11 | linjiang
# Processing Record 39 of Set 11 | dubrovnik
# Processing Record 40 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 42 of Set 11 | saint-georges
# Processing Record 43 of Set 11 | liwale
# Processing Record 44 of Set 11 | giyani
# Processing Record 45 of Set 11 | dauriya
# Processing Record 46 of Set 11 | terskaya
# Processing Record 47 of Set 11 | akyab
# Processing Record 48 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 11 | lorengau
# Processing Record 50 of Set 11 | raymondville
# Processing Record 1 of Set 12 | rawson
# Processing Record 2 of Set 12 | butembo
# Processing Record 3 of Set 12 | zheleznodorozhnyy
# Processing Record 4 of Set 12 | kaitangata
# Processing Record 5 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 12 | bambanglipuro
# Processing Record 7 of Set 12 | tabou
# Processing Record 8 of Set 12 | dubrovka
# Processing Record 9 of Set 12 | kharhial
# Processing Record 10 of Set 12 | mtimbira
# Processing Record 11 of Set 12 | wigston
# Processing Record 12 of Set 12 | lander
# Processing Record 13 of Set 12 | hami
# Processing Record 14 of Set 12 | okulovka
# Processing Record 15 of Set 12 | xining
# Processing Record 16 of Set 12 | gorontalo
# Processing Record 17 of Set 12 | rey bouba
# Processing Record 18 of Set 12 | kholodnyy
# Processing Record 19 of Set 12 | nacala
# Processing Record 20 of Set 12 | severnoye
# Processing Record 21 of Set 12 | phichit
# Processing Record 22 of Set 12 | biak
# Processing Record 23 of Set 12 | aromashevo
# Processing Record 24 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 12 | bar harbor
# Processing Record 26 of Set 12 | kantang
# Processing Record 27 of Set 12 | erzin
# Processing Record 28 of Set 12 | liaocheng
# Processing Record 29 of Set 12 | ambon
# Processing Record 30 of Set 12 | sidney
# Processing Record 31 of Set 12 | noumea
# Processing Record 32 of Set 12 | kaya
# Processing Record 33 of Set 12 | ayan
# Processing Record 34 of Set 12 | nilanga
# Processing Record 35 of Set 12 | navolato
# Processing Record 36 of Set 12 | islamkot
# Processing Record 37 of Set 12 | ambulu
# Processing Record 38 of Set 12 | north bend
# Processing Record 39 of Set 12 | ashland
# Processing Record 40 of Set 12 | farias brito
# Processing Record 41 of Set 12 | dauphin
# Processing Record 42 of Set 12 | iralaya
# Processing Record 43 of Set 12 | alnavar
# Processing Record 44 of Set 12 | rodino
# Processing Record 45 of Set 12 | yamada
# Processing Record 46 of Set 12 | arman
# Processing Record 47 of Set 12 | colwyn bay
# Processing Record 48 of Set 12 | nishihara
# Processing Record 49 of Set 12 | labrea
# Processing Record 50 of Set 12 | acapulco
# Processing Record 1 of Set 13 | samarai
# Processing Record 2 of Set 13 | farafangana
# Processing Record 3 of Set 13 | vardo
# Processing Record 4 of Set 13 | bathsheba
# Processing Record 5 of Set 13 | sao miguel do araguaia
# Processing Record 6 of Set 13 | gao
# Processing Record 7 of Set 13 | jawar
# Processing Record 8 of Set 13 | bardiyah
# Processing Record 9 of Set 13 | cabo san lucas
# Processing Record 10 of Set 13 | durango
# Processing Record 11 of Set 13 | isangel
# Processing Record 12 of Set 13 | pilar
# Processing Record 13 of Set 13 | casas grandes
# Processing Record 14 of Set 13 | ruian
# City not found. Skipping...
# Processing Record 15 of Set 13 | nurota
# Processing Record 16 of Set 13 | barcelos
# Processing Record 17 of Set 13 | emerald
# Processing Record 18 of Set 13 | massaguet
# Processing Record 19 of Set 13 | lompoc
# Processing Record 20 of Set 13 | amahai
# Processing Record 21 of Set 13 | rocha
# Processing Record 22 of Set 13 | rapid valley
# Processing Record 23 of Set 13 | malaya serdoba
# Processing Record 24 of Set 13 | basco
# Processing Record 25 of Set 13 | rio gallegos
# Processing Record 26 of Set 13 | ovre ardal
# Processing Record 27 of Set 13 | barao de melgaco
# Processing Record 28 of Set 13 | mattru
# Processing Record 29 of Set 13 | haines junction
# Processing Record 30 of Set 13 | kimbe
# Processing Record 31 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 32 of Set 13 | santarem
# Processing Record 33 of Set 13 | darhan
# Processing Record 34 of Set 13 | agirish
# Processing Record 35 of Set 13 | svetlogorsk
# Processing Record 36 of Set 13 | dolores
# Processing Record 37 of Set 13 | lerwick
# Processing Record 38 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 39 of Set 13 | zhigansk
# Processing Record 40 of Set 13 | challans
# Processing Record 41 of Set 13 | beisfjord
# Processing Record 42 of Set 13 | kindu
# Processing Record 43 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 13 | coolum beach
# Processing Record 45 of Set 13 | plock
# Processing Record 46 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 47 of Set 13 | yalutorovsk
# Processing Record 48 of Set 13 | umred
# Processing Record 49 of Set 13 | abu kamal
# Processing Record 50 of Set 13 | ajdabiya
# Processing Record 1 of Set 14 | mudgee
# Processing Record 2 of Set 14 | nakamura
# Processing Record 3 of Set 14 | tatawin
# Processing Record 4 of Set 14 | aksu
# Processing Record 5 of Set 14 | wajid
# Processing Record 6 of Set 14 | roald
# Processing Record 7 of Set 14 | necochea
# Processing Record 8 of Set 14 | alugan
# Processing Record 9 of Set 14 | ayaviri
# Processing Record 10 of Set 14 | fort nelson
# Processing Record 11 of Set 14 | rioja
# Processing Record 12 of Set 14 | moberly
# Processing Record 13 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 14 | maposeni
# Processing Record 15 of Set 14 | sendafa
# Processing Record 16 of Set 14 | lipin bor
# Processing Record 17 of Set 14 | pacific grove
# Processing Record 18 of Set 14 | oudtshoorn
# Processing Record 19 of Set 14 | cherepovets
# Processing Record 20 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 21 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 14 | brodokalmak
# Processing Record 23 of Set 14 | flin flon
# Processing Record 24 of Set 14 | cherusti
# Processing Record 25 of Set 14 | hofn
# Processing Record 26 of Set 14 | lubango
# Processing Record 27 of Set 14 | bosaso
# Processing Record 28 of Set 14 | margate
# Processing Record 29 of Set 14 | padang
# Processing Record 30 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 31 of Set 14 | hargeysa
# Processing Record 32 of Set 14 | hobyo
# Processing Record 33 of Set 14 | talaya
# Processing Record 34 of Set 14 | rusape
# Processing Record 35 of Set 14 | ville-marie
# Processing Record 36 of Set 14 | lilongwe
# Processing Record 37 of Set 14 | harrogate
# Processing Record 38 of Set 14 | amapa
# Processing Record 39 of Set 14 | capissayan
# Processing Record 40 of Set 14 | porto walter
# Processing Record 41 of Set 14 | rawlins
# Processing Record 42 of Set 14 | uruzgan
# Processing Record 43 of Set 14 | verkhnyaya inta
# Processing Record 44 of Set 14 | okha
# Processing Record 45 of Set 14 | kingisepp
# Processing Record 46 of Set 14 | mulchen
# Processing Record 47 of Set 14 | hit
# Processing Record 48 of Set 14 | mkushi
# Processing Record 49 of Set 14 | roros
# Processing Record 50 of Set 14 | clonakilty
# Processing Record 1 of Set 15 | gamba
# Processing Record 2 of Set 15 | lasa
# Processing Record 3 of Set 15 | miyako
# Processing Record 4 of Set 15 | bougouni
# Processing Record 5 of Set 15 | show low
# Processing Record 6 of Set 15 | vestmannaeyjar
# Processing Record 7 of Set 15 | nemuro
# Processing Record 8 of Set 15 | talawdi
# City not found. Skipping...
# Processing Record 9 of Set 15 | uvalde
# Processing Record 10 of Set 15 | marsh harbour
# Processing Record 11 of Set 15 | peniche
# Processing Record 12 of Set 15 | banda aceh
# Processing Record 13 of Set 15 | olga
# Processing Record 14 of Set 15 | gazli
# Processing Record 15 of Set 15 | lanigan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 657

# %%
# Convert the array of dictionaries into a Pandas data frame

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Busselton      AU -33.6500  115.3333     59.32        82         100
# 1    Saskylakh      RU  71.9167  114.0833     54.63        63         100
# 2   Chokurdakh      RU  70.6333  147.9167     57.15        38          23
# 3        Salur      IN  18.5333   83.2167     87.82        67         100
# 4  Yellowknife      CA  62.4560 -114.3525     55.92        76          75
# 5       Dikson      RU  73.5069   80.5464     52.30        73          37
# 6        Abapo      BO -18.8333  -63.4667     55.38        78           1
# 7  Fredericton      CA  45.9454  -66.6656     65.82        94         100
# 8      Chapais      CA  49.7834  -74.8492     58.78        92         100
# 9    Contamana      PE  -7.3333  -75.0167     70.86        84          80
#
#    Wind Speed Current Description
# 0       13.29     overcast clouds
# 1        7.23     overcast clouds
# 2       14.61          few clouds
# 3        3.33       moderate rain
# 4        0.00       broken clouds
# 5        8.10          light rain
# 6        3.00           clear sky
# 7        6.91                mist
# 8       10.89     overcast clouds
# 9        1.70       broken clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label='City_ID')
